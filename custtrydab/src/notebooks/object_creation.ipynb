# %%
dbutils.widgets.text('catalog_name','feature_dab')

# %%
catalog_name = dbutils.widgets.get('catalog_name')

# %%
spark.sql(f'create catalog if not exists {catalog_name}')
spark.sql(f'create schema if not exists {catalog_name}.brnz')
spark.sql(f'create schema if not exists {catalog_name}.slvr')
spark.sql(f'create schema if not exists {catalog_name}.gold')
